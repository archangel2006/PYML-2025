# %% [markdown]
# <a href="https://colab.research.google.com/github/archangel2006/PYML-2025/blob/main/PYML1%20(Loading%20%26%20Reading%20Datasets).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Working With PANDAS

# %%
# Loading Data Using Pandas

import pandas as pd
df=pd.read_csv('/content/House Price Prediction Dataset.csv')

# %%
df.head() # Print First 5 Rows Of Dataset
# Out:
#    Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0   1  1360         5          4       3       1970  Downtown  Excellent
# 1   2  4272         5          4       3       1958  Downtown  Excellent
# 2   3  3592         2          2       3       1938  Downtown       Good
# 3   4   966         4          2       2       1902  Suburban       Fair
# 4   5  4926         1          4       2       1975  Downtown       Fair
#
#   Garage   Price
# 0     No  149919
# 1     No  424998
# 2     No  266746
# 3    Yes  244020
# 4    Yes  636056

# %%
df.sample(5) # Prints Any 'n' Rows Of Data
# Out:
#         Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 1747  1748  4003         4          4       3       1956     Urban       Poor
# 1227  1228  1487         3          4       3       2002     Urban       Poor
# 1902  1903   956         3          2       1       1936     Urban       Good
# 904    905  1454         3          3       2       1917  Downtown  Excellent
# 819    820  1422         3          4       1       1993     Urban       Good
#
#      Garage   Price
# 1747     No  176298
# 1227     No  520970
# 1902     No  371961
# 904     Yes  196539
# 819     Yes  922811
